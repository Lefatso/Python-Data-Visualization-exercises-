# %% [markdown]
# # Data Filtering and Selection

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
employee_data = pd.read_excel("Employee Sample Data.xlsx")

# %%
# 8.
employee_IT_filter = employee_data[employee_data['Department'] == "IT"]
employee_IT_filter
# Out:
#        EEID          Full Name                 Job Title Department  \
# 0    E02387        Emily Davis                Sr. Manger         IT
# 1    E04105      Theodore Dinh       Technical Architect         IT
# 3    E02832    Penelope Jordan  Computer Systems Manager         IT
# 6    E01550        Ruby Barnes                   Manager         IT
# 18   E04116       David Barnes                  Director         IT
# ..      ...                ...                       ...        ...
# 985  E00156      Madelyn Scott                Sr. Manger         IT
# 990  E01578       Anthony Hong                Sr. Manger         IT
# 992  E03058      Robert Wright       Technical Architect         IT
# 993  E04762  Audrey Richardson                  Director         IT
# 994  E01148     Scarlett Kumar           Systems Analyst         IT
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
# 9.
salary_filter = employee_data[(employee_data['Annual Salary'] >= 100000) & (employee_data['Annual Salary'] <= 150000)]
salary_filter
# Out:
#        EEID        Full Name          Job Title       Department  \
# 0    E02387      Emily Davis         Sr. Manger               IT
# 6    E01550      Ruby Barnes            Manager               IT
# 8    E04533    Easton Bailey            Manager       Accounting
# 11   E03344    Camila Rogers  Controls Engineer      Engineering
# 12   E00530        Eli Jones            Manager  Human Resources
# ..      ...              ...                ...              ...
# 978  E00682  Sofia Fernandez            Manager       Accounting
# 980  E00785     Hannah Hoang            Manager       Accounting
# 983  E02703      Austin Vang            Manager        Marketing
# 985  E00156    Madelyn Scott         Sr. Manger               IT
# 990  E01578     Anthony Hong         Sr. Manger               IT
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
#10.
filter_2015_employee = employee_data[employee_data['Hire Date'] > '2015-01-01']
filter_2015_employee
# Out:
#        EEID          Full Name                 Job Title  Department  \
# 0    E02387        Emily Davis                Sr. Manger          IT
# 3    E02832    Penelope Jordan  Computer Systems Manager          IT
# 5    E00644       Joshua Gupta    Account Representative       Sales
# 6    E01550        Ruby Barnes                   Manager          IT
# 7    E04332        Luke Martin                   Analyst     Finance
# ..      ...                ...                       ...         ...
# 992  E03058      Robert Wright       Technical Architect          IT
# 993  E04762  Audrey Richardson                  Director          IT
# 995  E03094       Wesley Young               Sr. Analyst   Marketing
# 997  E04398        Oliver Yang                  Director   Marketing
# 999  E03545        Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
#11.
multi_col_filter =  employee_data[(employee_data['Gender'] == 'Female') & (employee_data['Department'] =='Sales') & (employee_data['Bonus %'] > 0.1)]
multi_col_filter
# Out:
#        EEID         Full Name       Job Title Department  \
# 21   E04732        Eva Rivera        Director      Sales
# 95   E01427         Mia Cheng      Sr. Manger      Sales
# 99   E03890      Nevaeh Jones  Vice President      Sales
# 113  E02850       Evelyn Dinh        Director      Sales
# 146  E00957     Genesis Perry      Sr. Manger      Sales
# 169  E03956     Everly Walker      Sr. Manger      Sales
# 193  E02791     Aubrey Romero        Director      Sales
# 197  E00752          Luna Liu  Vice President      Sales
# 248  E02285           Aria Xi        Director      Sales
# 272  E04127      Emery Acosta  Vice President      Sales
# 312  E03081        Ayla Brown      Sr. Manger      Sales
# 319  E04419      Sophia Ahmed      Sr. Manger      Sales
# 331  E03251       Ruby Medina        Director      Sales
# 423  E04101     Olivia Harris        Director      Sales
# 426  E01238    Eloise Griffin        Director      Sales
# ...

# %%
# 12.
new_dataFrame = employee_data[['Full Name','Job Title','Department','Annual Salary']]
new_dataFrame
# Out:
#            Full Name                 Job Title  Department  Annual Salary
# 0        Emily Davis                Sr. Manger          IT         141604
# 1      Theodore Dinh       Technical Architect          IT          99975
# 2       Luna Sanders                  Director     Finance         163099
# 3    Penelope Jordan  Computer Systems Manager          IT          84913
# 4          Austin Vo               Sr. Analyst     Finance          95409
# ..               ...                       ...         ...            ...
# 995     Wesley Young               Sr. Analyst   Marketing          98427
# 996     Lillian Khan                   Analyst     Finance          47387
# 997      Oliver Yang                  Director   Marketing         176710
# 998      Lily Nguyen               Sr. Analyst     Finance          95960
# 999      Sofia Cheng            Vice President  Accounting         216195
#
# [1000 rows x 4 columns]
